# %%
import Hotel_Room_Booking as r

# %%
r.main_menu()
# Out:
# =====Hotel Booking System=====
#
# 1. Show Rooms
# 2. Book a Room
# 3. Cancel Booking
# 4. View Bookings
# 5. View Overall Bookings
# 6. Exit Menu
# Enter Your Choice (1-6): 1
# <----- Available Rooms ----->
# Room Type: Standard
# 	Price/night: Rs.1400.00
# 	Available: 10
# Room Type: Deluxe
# 	Price/night: Rs.2000.00
# 	Available: 5
# Room Type: Suite
# 	Price/night: Rs.5000.00
# 	Available: 2
#
#
# =====Hotel Booking System=====
#
# 1. Show Rooms
# 2. Book a Room
# 3. Cancel Booking
# 4. View Bookings
# 5. View Overall Bookings
# 6. Exit Menu
# Enter Your Choice (1-6): 2
# <----- Book a Room ----->
# Please enter your name: karthik
# Please enter type of room: Standard
# Please enter number of nights of stay: 2
# Confirm booking? (y/n): y
# Booking successful!
# Booking ID: B20251110123800
# Guest: Karthik
# Room : Standard, Nights: 2
# Total Bill (incl. taxes): Rs.3136.00
#
#
# =====Hotel Booking System=====
#
# 1. Show Rooms
# 2. Book a Room
# 3. Cancel Booking
# ...
